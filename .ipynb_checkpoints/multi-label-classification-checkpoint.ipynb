# %%
import matplotlib
matplotlib.use("Agg")

import matplotlib.pyplot as plt
import numpy as np
import random
import pickle
import cv2
import os
from imutils import paths

from Model import SmallerVGGNet

from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
EPOCHS = 75
LEARNING_RATE = 0.001
BATCH_SIZE = 32
IMAGE_DIMS = (96, 96, 3)

# %%
paths = sorted(list(paths.list_images("dataset")))

# %%
random.seed(2)
random.shuffle(paths)

# %%
paths
# Out:
# ['dataset\\red_truck\\images (81).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.318.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.429.jpg',
#  'dataset\\red_truck\\images (30).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.127.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.902.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.521.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230015.976.jpg',
#  'dataset\\yellow_sportscar\\2Q__ (1).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225953.917.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.745.jpg',
#  'dataset\\green_bicycle\\arrow_down.png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225532.472.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225422.484.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225420.198.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230022.410.jpg',
#  'dataset\\red_truck\\images (83).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225357.304.jpg',
#  'dataset\\green_bicycle\\images (55).jpg',
#  'dataset\\red_truck\\9k_ (4).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225535.745.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225419.997.jpg',
#  'dataset\\red_truck\\images (56).jpg',
#  'dataset\\red_truck\\2Q__.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.436.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.827.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.930.jpg',
#  'dataset\\yellow_sportscar\\9k_ (8).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225550.490.jpg',
#  'dataset\\yellow_sportscar\\images (14).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225416.593.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225358.255.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225417.001.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225550.840.jpg',
#  'dataset\\green_bicycle\\images (10).png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230020.259.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225529.612.jpg',
#  'dataset\\green_bicycle\\images (44).jpg',
#  'dataset\\yellow_sportscar\\images (6).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225956.132.jpg',
#  'dataset\\yellow_sportscar\\images (65).jpg',
#  'dataset\\green_bicycle\\images (65).jpg',
#  'dataset\\green_bicycle\\Z (8).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230006.658.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225409.590.jpg',
#  'dataset\\green_bicycle\\images.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.117.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225955.589.jpg',
#  'dataset\\red_truck\\images (93).jpg',
#  'dataset\\yellow_sportscar\\images (90).jpg',
#  'dataset\\green_bicycle\\images (45).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225546.239.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.075.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230021.481.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225423.198.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.897.jpg',
#  'dataset\\yellow_sportscar\\images (20).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225406.963.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225953.232.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225957.544.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225544.780.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225359.220.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.398.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230022.470.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225954.753.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230001.198.jpg',
#  'dataset\\yellow_sportscar\\images (15).jpg',
#  'dataset\\yellow_sportscar\\images (44).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225353.541.jpg',
#  'dataset\\yellow_sportscar\\images (29).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230009.822.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230016.109.jpg',
#  'dataset\\green_bicycle\\images (7).png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.843.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225958.096.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.688.jpg',
#  'dataset\\red_truck\\9k_ (1).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.148.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225533.138.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225957.415.jpg',
#  'dataset\\green_bicycle\\images (82).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225357.820.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230021.139.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225529.249.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225546.134.jpg',
#  'dataset\\green_bicycle\\Z (10).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.694.jpg',
#  'dataset\\yellow_sportscar\\photo_camera_grey600_24dp.png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225544.272.jpg',
#  'dataset\\yellow_sportscar\\images (93).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225527.370.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225545.806.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230016.499.jpg',
#  'dataset\\yellow_sportscar\\images (86).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230015.333.jpg',
#  'dataset\\red_truck\\images.png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.633.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225400.067.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225417.336.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230003.601.jpg',
#  'dataset\\yellow_sportscar\\images (39).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.372.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.392.jpg',
#  'dataset\\green_bicycle\\images (10).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225411.905.jpg',
#  'dataset\\green_bicycle\\images (48).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225532.981.jpg',
#  'dataset\\red_truck\\images (8).jpg',
#  'dataset\\yellow_sportscar\\images (87).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230005.876.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225954.110.jpg',
#  'dataset\\green_bicycle\\images (79).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.208.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.103.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225351.085.jpg',
#  'dataset\\green_bicycle\\images (20).jpg',
#  'dataset\\green_bicycle\\images (54).jpg',
#  'dataset\\red_truck\\images (82).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.190.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225952.471.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.683.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.990.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.493.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225956.833.jpg',
#  'dataset\\green_bicycle\\images (8).png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230023.123.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225548.912.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225552.446.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225402.158.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225400.193.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225527.838.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.572.jpg',
#  'dataset\\red_truck\\images (53).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225421.532.jpg',
#  'dataset\\green_bicycle\\2Q__ (6).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230001.899.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230020.834.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225401.562.jpg',
#  'dataset\\green_bicycle\\images (96).jpg',
#  'dataset\\yellow_sportscar\\images (31).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.068.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.356.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.246.jpg',
#  'dataset\\yellow_sportscar\\images (2).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225534.035.jpg',
#  'dataset\\red_truck\\Z (3).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225408.076.jpg',
#  'dataset\\green_bicycle\\images (97).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.779.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.477.jpg',
#  'dataset\\red_truck\\Z (1).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.575.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230022.166.jpg',
#  'dataset\\green_bicycle\\2Q__ (1).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225535.852.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.400.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225416.340.jpg',
#  'dataset\\yellow_sportscar\\images (99).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.839.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225352.724.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.928.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225358.896.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230014.426.jpg',
#  'dataset\\green_bicycle\\images (17).png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.835.jpg',
#  'dataset\\red_truck\\wPm5O9r5Qj0DwAAAABJRU5ErkJggg__.png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.651.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230006.465.jpg',
#  'dataset\\yellow_sportscar\\images (98).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225533.469.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230008.798.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.000.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225356.663.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230010.233.jpg',
#  'dataset\\red_truck\\images (71).jpg',
#  'dataset\\yellow_sportscar\\9k_ (5).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225400.506.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225530.703.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225351.793.jpg',
#  'dataset\\red_truck\\images (33).jpg',
#  'dataset\\yellow_sportscar\\images (18).jpg',
#  'dataset\\red_truck\\images (26).jpg',
#  'dataset\\yellow_sportscar\\images (40).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225546.392.jpg',
#  'dataset\\red_truck\\images (66).jpg',
#  'dataset\\green_bicycle\\images (43).jpg',
#  'dataset\\green_bicycle\\images (12).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230021.266.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.337.jpg',
#  'dataset\\green_bicycle\\images (2).png',
#  'dataset\\red_truck\\images (19).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230012.693.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225953.638.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.147.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.764.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225952.881.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.000.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225403.644.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230009.938.jpg',
#  'dataset\\yellow_sportscar\\images (4).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.989.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.798.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225412.699.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225401.001.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.936.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.208.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225351.491.jpg',
#  'dataset\\green_bicycle\\2Q__ (8).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225407.445.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.403.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225420.578.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.869.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.419.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.045.jpg',
#  'dataset\\red_truck\\images (99).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230000.933.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225424.143.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225420.252.jpg',
#  'dataset\\yellow_sportscar\\images (11).jpg',
#  'dataset\\yellow_sportscar\\images (27).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230001.700.jpg',
#  'dataset\\yellow_sportscar\\images (35).jpg',
#  'dataset\\red_truck\\images (80).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.059.jpg',
#  'dataset\\green_bicycle\\images (13).png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.046.jpg',
#  'dataset\\yellow_sportscar\\photo.png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.501.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.055.jpg',
#  'dataset\\green_bicycle\\images (40).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225532.195.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.323.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.923.jpg',
#  'dataset\\red_truck\\images (38).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.623.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.035.jpg',
#  'dataset\\red_truck\\p1_6234ef59.png',
#  'dataset\\red_truck\\images - 2019-10-16T225407.110.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230021.684.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225421.913.jpg',
#  'dataset\\green_bicycle\\2Q__ (3).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225417.403.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.484.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.026.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.385.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225420.624.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225352.089.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225955.519.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225953.791.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225400.600.jpg',
#  'dataset\\green_bicycle\\images (59).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225355.632.jpg',
#  'dataset\\green_bicycle\\images (94).jpg',
#  'dataset\\green_bicycle\\images (4).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230006.141.jpg',
#  'dataset\\red_truck\\images (27).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225533.831.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.663.jpg',
#  'dataset\\yellow_sportscar\\2Q__ (5).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.971.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225534.420.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.843.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230012.758.jpg',
#  'dataset\\green_bicycle\\images (35).jpg',
#  'dataset\\yellow_sportscar\\images (82).jpg',
#  'dataset\\yellow_sportscar\\images (23).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225534.379.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225540.457.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225350.767.jpg',
#  'dataset\\red_truck\\images (94).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225529.874.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225400.402.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225413.768.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225416.453.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225412.120.jpg',
#  'dataset\\red_truck\\2Q__ (1).jpg',
#  'dataset\\green_bicycle\\images (77).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.838.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225550.164.jpg',
#  'dataset\\yellow_sportscar\\images (79).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225955.791.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225413.597.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230010.683.jpg',
#  'dataset\\yellow_sportscar\\Z (2).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.338.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.026.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225416.656.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230000.673.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225400.925.jpg',
#  'dataset\\yellow_sportscar\\images (68).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225403.586.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225414.759.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225409.957.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225414.987.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225419.930.jpg',
#  'dataset\\red_truck\\images (85).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225529.996.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.923.jpg',
#  'dataset\\red_truck\\images (21).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225402.748.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230010.835.jpg',
#  'dataset\\green_bicycle\\9k_ (5).jpg',
#  'dataset\\red_truck\\Z (10).jpg',
#  'dataset\\red_truck\\images (69).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.280.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230013.625.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.570.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225413.480.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225355.804.jpg',
#  'dataset\\green_bicycle\\images (52).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225419.274.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225553.379.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.655.jpg',
#  'dataset\\red_truck\\Z (9).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225406.230.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225958.355.jpg',
#  'dataset\\green_bicycle\\images (37).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225421.150.jpg',
#  'dataset\\green_bicycle\\images (8).jpg',
#  'dataset\\green_bicycle\\9k_ (2).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230021.850.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.327.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.085.jpg',
#  'dataset\\yellow_sportscar\\images (81).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.400.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230015.473.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.838.jpg',
#  'dataset\\red_truck\\images (16).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230020.700.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225412.337.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225527.084.jpg',
#  'dataset\\yellow_sportscar\\images (52).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230006.408.jpg',
#  'dataset\\red_truck\\images (5).png',
#  'dataset\\yellow_sportscar\\keyboard_arrow_right_grey600_24dp.png',
#  'dataset\\red_truck\\images - 2019-10-16T225406.358.jpg',
#  'dataset\\red_truck\\images (52).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225546.720.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225400.694.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.170.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225357.887.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225415.302.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230003.964.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225411.221.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.782.jpg',
#  'dataset\\green_bicycle\\Z (4).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230023.376.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230010.502.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225548.034.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225423.430.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225407.025.jpg',
#  'dataset\\red_truck\\images (98).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225532.877.jpg',
#  'dataset\\yellow_sportscar\\images (17).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225545.396.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225541.191.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230005.119.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225356.235.jpg',
#  'dataset\\red_truck\\images (7).png',
#  'dataset\\red_truck\\images (72).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.616.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225551.467.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.055.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225529.936.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225351.007.jpg',
#  'dataset\\green_bicycle\\images (66).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225357.248.jpg',
#  'dataset\\green_bicycle\\images (78).jpg',
#  'dataset\\green_bicycle\\Z (11).jpg',
#  'dataset\\red_truck\\photo_camera_grey600_24dp.png',
#  'dataset\\red_truck\\images - 2019-10-16T225359.461.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225402.859.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.078.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225955.249.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225408.273.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.433.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225545.864.jpg',
#  'dataset\\yellow_sportscar\\images (60).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.320.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.062.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.630.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225529.774.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225958.555.jpg',
#  'dataset\\red_truck\\images (68).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.563.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230008.290.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225400.123.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225353.403.jpg',
#  'dataset\\yellow_sportscar\\images (83).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.352.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225407.506.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225413.423.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230013.679.jpg',
#  'dataset\\yellow_sportscar\\images (21).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225355.029.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.742.jpg',
#  'dataset\\green_bicycle\\2Q__ (5).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225403.456.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.349.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.561.jpg',
#  'dataset\\green_bicycle\\Z (13).jpg',
#  'dataset\\green_bicycle\\9k_ (4).jpg',
#  'dataset\\yellow_sportscar\\images (9).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.746.jpg',
#  'dataset\\red_truck\\images (54).jpg',
#  'dataset\\yellow_sportscar\\images (63).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225356.874.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225351.297.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230009.670.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225408.399.jpg',
#  'dataset\\yellow_sportscar\\Z (4).jpg',
#  'dataset\\yellow_sportscar\\images (49).jpg',
#  'dataset\\red_truck\\images (12).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.104.jpg',
#  'dataset\\yellow_sportscar\\Z (6).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230024.308.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225540.786.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225411.838.jpg',
#  'dataset\\yellow_sportscar\\9k_ (10).jpg',
#  'dataset\\red_truck\\images (47).jpg',
#  'dataset\\yellow_sportscar\\images (66).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225405.402.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225419.017.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225552.410.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225409.082.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225552.505.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230010.891.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.049.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225953.104.jpg',
#  'dataset\\yellow_sportscar\\images (30).jpg',
#  'dataset\\green_bicycle\\images (31).jpg',
#  'dataset\\yellow_sportscar\\9k_ (7).jpg',
#  'dataset\\red_truck\\Z (5).jpg',
#  'dataset\\red_truck\\images (75).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230011.561.jpg',
#  'dataset\\yellow_sportscar\\images (72).jpg',
#  'dataset\\green_bicycle\\images (13).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.618.jpg',
#  'dataset\\red_truck\\images (20).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.777.jpg',
#  'dataset\\green_bicycle\\images (17).jpg',
#  'dataset\\yellow_sportscar\\2Q__ (4).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225529.213.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.680.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.704.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.942.jpg',
#  'dataset\\red_truck\\images (96).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225421.212.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225415.637.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225527.249.jpg',
#  'dataset\\green_bicycle\\images (6).png',
#  'dataset\\red_truck\\images - 2019-10-16T225359.860.jpg',
#  'dataset\\red_truck\\images (79).jpg',
#  'dataset\\red_truck\\images (22).jpg',
#  'dataset\\green_bicycle\\Z (12).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225406.296.jpg',
#  'dataset\\green_bicycle\\9k_ (6).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225549.261.jpg',
#  'dataset\\red_truck\\images (86).jpg',
#  'dataset\\green_bicycle\\images (67).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225359.804.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225411.602.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.427.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225532.564.jpg',
#  'dataset\\yellow_sportscar\\images (41).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230006.788.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225538.028.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225350.695.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230003.667.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225955.682.jpg',
#  'dataset\\yellow_sportscar\\9k_ (4).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225955.867.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.111.jpg',
#  'dataset\\green_bicycle\\images (89).jpg',
#  'dataset\\yellow_sportscar\\images (89).jpg',
#  'dataset\\green_bicycle\\images (70).jpg',
#  'dataset\\red_truck\\images (61).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225550.122.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.394.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225956.992.jpg',
#  'dataset\\green_bicycle\\Z (5).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225356.592.jpg',
#  'dataset\\yellow_sportscar\\images (34).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225540.275.jpg',
#  'dataset\\red_truck\\images (55).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.805.jpg',
#  'dataset\\green_bicycle\\images (14).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225423.784.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.414.jpg',
#  'dataset\\red_truck\\images (95).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.206.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225415.038.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.702.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.328.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225401.254.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225407.684.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225538.701.jpg',
#  'dataset\\red_truck\\9k_ (2).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.570.jpg',
#  'dataset\\red_truck\\images (37).jpg',
#  'dataset\\red_truck\\Z (7).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225530.886.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.048.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225357.709.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.420.jpg',
#  'dataset\\red_truck\\images (74).jpg',
#  'dataset\\yellow_sportscar\\images (88).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230014.842.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230008.941.jpg',
#  'dataset\\red_truck\\images (45).jpg',
#  'dataset\\green_bicycle\\images (30).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.624.jpg',
#  'dataset\\red_truck\\images (65).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225414.026.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.067.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230000.988.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.265.jpg',
#  'dataset\\red_truck\\images (63).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225417.645.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225530.203.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230000.276.jpg',
#  'dataset\\yellow_sportscar\\images (26).jpg',
#  'dataset\\red_truck\\images (25).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225415.992.jpg',
#  'dataset\\red_truck\\911e3628e6.png',
#  'dataset\\red_truck\\images - 2019-10-16T225416.728.jpg',
#  'dataset\\green_bicycle\\images (42).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230005.656.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230023.170.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225358.521.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.994.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.623.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225408.329.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225546.182.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225413.103.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.918.jpg',
#  'dataset\\green_bicycle\\Z (1).jpg',
#  'dataset\\red_truck\\2Q__ (2).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230020.520.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225551.703.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.955.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230012.348.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230003.244.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.006.jpg',
#  'dataset\\green_bicycle\\images (21).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225527.136.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225957.482.jpg',
#  'dataset\\green_bicycle\\Z (7).jpg',
#  'dataset\\green_bicycle\\9k_ (3).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225544.208.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.708.jpg',
#  'dataset\\red_truck\\images (39).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225958.418.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225414.145.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225419.345.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225534.096.jpg',
#  'dataset\\red_truck\\2Q__ (3).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230015.406.jpg',
#  'dataset\\red_truck\\images (6).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225534.513.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230008.743.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225357.193.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225408.445.jpg',
#  'dataset\\yellow_sportscar\\images (78).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230022.869.jpg',
#  'dataset\\red_truck\\2Q__ (8).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225956.690.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.949.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.986.jpg',
#  'dataset\\yellow_sportscar\\images (33).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230012.513.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.317.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230023.226.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225954.639.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225401.188.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.905.jpg',
#  'dataset\\yellow_sportscar\\images (37).jpg',
#  'dataset\\red_truck\\images (3).png',
#  'dataset\\red_truck\\images - 2019-10-16T225403.757.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225424.198.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230003.736.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225421.971.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230020.315.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225958.946.jpg',
#  'dataset\\green_bicycle\\9k_ (7).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225352.415.jpg',
#  'dataset\\green_bicycle\\images (76).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.563.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230024.028.jpg',
#  'dataset\\red_truck\\images.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225545.258.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.763.jpg',
#  'dataset\\green_bicycle\\images (3).png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225549.542.jpg',
#  'dataset\\yellow_sportscar\\images (16).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230005.235.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230010.298.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225953.498.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225958.477.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225412.170.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.282.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225359.161.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225548.600.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225403.254.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225356.816.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225355.922.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225957.124.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225530.507.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225422.544.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225353.475.jpg',
#  'dataset\\yellow_sportscar\\images (80).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.529.jpg',
#  'dataset\\red_truck\\images (41).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225358.653.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230003.837.jpg',
#  'dataset\\green_bicycle\\Z (2).jpg',
#  'dataset\\yellow_sportscar\\arrow_down.png',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225533.530.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225530.835.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225420.687.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225957.049.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.867.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225353.762.jpg',
#  'dataset\\red_truck\\images (51).jpg',
#  'dataset\\red_truck\\images (97).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.626.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.268.jpg',
#  'dataset\\red_truck\\images (49).jpg',
#  'dataset\\green_bicycle\\images (9).jpg',
#  'dataset\\yellow_sportscar\\images (48).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230000.548.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.007.jpg',
#  'dataset\\red_truck\\Z (11).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225539.575.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225408.628.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225552.106.jpg',
#  'dataset\\red_truck\\2Q__ (5).jpg',
#  'dataset\\green_bicycle\\images (58).jpg',
#  'dataset\\red_truck\\images (60).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225416.039.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.687.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225541.579.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.469.jpg',
#  'dataset\\green_bicycle\\images (83).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225540.567.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225405.469.jpg',
#  'dataset\\yellow_sportscar\\images (38).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230012.044.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.498.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225408.023.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230016.300.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225359.589.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225420.873.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225353.112.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225952.746.jpg',
#  'dataset\\green_bicycle\\images (61).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225541.729.jpg',
#  'dataset\\yellow_sportscar\\2Q__.jpg',
#  'dataset\\yellow_sportscar\\images (28).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225422.764.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.061.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225545.445.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225359.107.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.486.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225353.051.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.011.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225351.972.jpg',
#  'dataset\\green_bicycle\\images (18).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225958.692.jpg',
#  'dataset\\green_bicycle\\photo.png',
#  'dataset\\red_truck\\images - 2019-10-16T225401.526.jpg',
#  'dataset\\yellow_sportscar\\9k_ (9).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.497.jpg',
#  'dataset\\red_truck\\images (42).jpg',
#  'dataset\\green_bicycle\\images (84).jpg',
#  'dataset\\red_truck\\jW4YkWOPyr3WrUe0n3aAAAAAElFTkSuQmCC.png',
#  'dataset\\red_truck\\Z (4).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230015.533.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225415.104.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230001.561.jpg',
#  'dataset\\red_truck\\images (32).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230011.721.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.669.jpg',
#  'dataset\\green_bicycle\\2Q__ (7).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225544.160.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225533.761.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.980.jpg',
#  'dataset\\green_bicycle\\images (23).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.233.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225413.539.jpg',
#  'dataset\\green_bicycle\\images (9).png',
#  'dataset\\green_bicycle\\Z (9).jpg',
#  'dataset\\red_truck\\images (59).jpg',
#  'dataset\\green_bicycle\\images (90).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225533.876.jpg',
#  'dataset\\green_bicycle\\images (28).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230001.766.jpg',
#  'dataset\\red_truck\\2Q__ (7).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.969.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225535.901.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225545.761.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225412.405.jpg',
#  'dataset\\green_bicycle\\images (50).jpg',
#  'dataset\\yellow_sportscar\\images (12).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230021.208.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225548.996.jpg',
#  'dataset\\green_bicycle\\Z (3).jpg',
#  'dataset\\yellow_sportscar\\9k_.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.586.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.220.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225357.518.jpg',
#  'dataset\\green_bicycle\\images (62).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.895.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225534.798.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.762.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230008.348.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.350.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225552.187.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225553.065.jpg',
#  'dataset\\red_truck\\images (1).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225358.587.jpg',
#  'dataset\\green_bicycle\\images (73).jpg',
#  'dataset\\green_bicycle\\images (81).jpg',
#  'dataset\\yellow_sportscar\\images (1).png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230023.598.jpg',
#  'dataset\\green_bicycle\\images (64).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225550.892.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230023.674.jpg',
#  'dataset\\red_truck\\images (3).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.147.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230019.694.jpg',
#  'dataset\\yellow_sportscar\\p1_6234ef59.png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230023.813.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225359.733.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.674.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225540.832.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225356.924.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225422.819.jpg',
#  'dataset\\red_truck\\images (17).jpg',
#  'dataset\\red_truck\\images (84).jpg',
#  'dataset\\green_bicycle\\images (5).jpg',
#  'dataset\\red_truck\\images (92).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225352.473.jpg',
#  'dataset\\red_truck\\images (46).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225552.739.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225532.813.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.440.jpg',
#  'dataset\\red_truck\\2Q__ (6).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.791.jpg',
#  'dataset\\yellow_sportscar\\911e3628e6.png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230000.367.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225411.460.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225406.032.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225401.642.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225412.752.jpg',
#  'dataset\\yellow_sportscar\\images.png',
#  'dataset\\green_bicycle\\images (71).jpg',
#  'dataset\\red_truck\\images (73).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225419.222.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.111.jpg',
#  'dataset\\green_bicycle\\images (85).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.805.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225546.834.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230021.556.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225536.072.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225955.452.jpg',
#  'dataset\\green_bicycle\\images (95).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225540.522.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.819.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225355.262.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230015.635.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230011.621.jpg',
#  'dataset\\green_bicycle\\images (14).png',
#  'dataset\\red_truck\\images - 2019-10-16T225351.359.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225549.046.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230001.633.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225548.334.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.329.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.501.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225413.828.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225548.688.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.692.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225538.494.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225532.243.jpg',
#  'dataset\\green_bicycle\\images (92).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230002.750.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230011.082.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225551.341.jpg',
#  'dataset\\yellow_sportscar\\images (96).jpg',
#  'dataset\\green_bicycle\\images (53).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.067.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225957.764.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230009.535.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230014.049.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225544.838.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.313.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225415.927.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230006.202.jpg',
#  'dataset\\red_truck\\images (43).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.650.jpg',
#  'dataset\\red_truck\\images (9).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225530.935.jpg',
#  'dataset\\yellow_sportscar\\9k_ (12).jpg',
#  'dataset\\red_truck\\images (44).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225540.645.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230022.102.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225355.693.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225406.623.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225422.272.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225422.434.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230013.744.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225954.448.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230013.064.jpg',
#  'dataset\\green_bicycle\\images (60).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.992.jpg',
#  'dataset\\green_bicycle\\images (80).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.403.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225541.488.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225956.246.jpg',
#  'dataset\\green_bicycle\\images (47).jpg',
#  'dataset\\red_truck\\2Q__ (9).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230022.523.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230013.401.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225422.338.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225955.102.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225423.114.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.124.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225551.872.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225544.911.jpg',
#  'dataset\\yellow_sportscar\\images (19).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225357.644.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225551.210.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225352.602.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.554.jpg',
#  'dataset\\yellow_sportscar\\9k_ (11).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225402.305.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225405.913.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225538.929.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225401.135.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225401.909.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225405.659.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225414.344.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225404.827.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225534.135.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.186.jpg',
#  'dataset\\yellow_sportscar\\Z.jpg',
#  'dataset\\red_truck\\images (77).jpg',
#  'dataset\\yellow_sportscar\\Z (5).jpg',
#  'dataset\\red_truck\\images (90).jpg',
#  'dataset\\yellow_sportscar\\images (53).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.112.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230012.173.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225552.048.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225413.163.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.481.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.609.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230016.373.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225420.932.jpg',
#  'dataset\\red_truck\\images (50).jpg',
#  'dataset\\yellow_sportscar\\images (69).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.554.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225419.509.jpg',
#  'dataset\\yellow_sportscar\\9k_ (1).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225421.849.jpg',
#  'dataset\\green_bicycle\\images (91).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225417.956.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225956.187.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230015.770.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225534.998.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225358.464.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225405.729.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225956.606.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.651.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230001.406.jpg',
#  'dataset\\green_bicycle\\images (57).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225953.572.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230010.565.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225543.602.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225959.238.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.372.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225417.274.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225402.503.jpg',
#  'dataset\\green_bicycle\\images (87).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225550.437.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230006.838.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230022.660.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.597.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225954.229.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225531.552.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225419.388.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225553.162.jpg',
#  'dataset\\green_bicycle\\images (39).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230013.515.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230009.731.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225958.864.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230014.778.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225416.389.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230016.418.jpg',
#  'dataset\\yellow_sportscar\\9k_ (13).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225412.513.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225549.604.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225418.907.jpg',
#  'dataset\\green_bicycle\\images (68).jpg',
#  'dataset\\green_bicycle\\images (24).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230005.596.jpg',
#  'dataset\\red_truck\\images (28).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225528.260.jpg',
#  'dataset\\red_truck\\images (6).png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230024.161.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230000.860.jpg',
#  'dataset\\green_bicycle\\images (11).png',
#  'dataset\\red_truck\\images - 2019-10-16T225423.374.jpg',
#  'dataset\\green_bicycle\\images (49).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225353.338.jpg',
#  'dataset\\red_truck\\images (11).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.539.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225952.603.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225532.139.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225415.478.jpg',
#  'dataset\\red_truck\\images (34).jpg',
#  'dataset\\red_truck\\images (91).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.733.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225527.035.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225353.698.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225527.503.jpg',
#  'dataset\\green_bicycle\\images (51).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225414.696.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225537.729.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230017.847.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.687.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225355.865.jpg',
#  'dataset\\yellow_sportscar\\images (8).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225410.349.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225354.975.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230011.232.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230008.067.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225525.108.jpg',
#  'dataset\\yellow_sportscar\\images (74).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230003.549.jpg',
#  'dataset\\green_bicycle\\images (38).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225545.494.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.264.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225401.791.jpg',
#  'dataset\\red_truck\\images (40).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225527.909.jpg',
#  'dataset\\red_truck\\9k_ (5).jpg',
#  'dataset\\yellow_sportscar\\images (91).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225546.770.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.646.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230008.597.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225358.202.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225417.705.jpg',
#  'dataset\\yellow_sportscar\\images (22).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230022.736.jpg',
#  'dataset\\red_truck\\images (62).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225544.492.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225415.694.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.043.jpg',
#  'dataset\\green_bicycle\\icon_small.png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230015.076.jpg',
#  'dataset\\green_bicycle\\2Q__ (2).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.568.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225541.122.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225526.206.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225550.779.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T225953.164.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230007.163.jpg',
#  'dataset\\yellow_sportscar\\9k_ (3).jpg',
#  'dataset\\green_bicycle\\keyboard_arrow_right_grey600_24dp.png',
#  'dataset\\green_bicycle\\images - 2019-10-16T230016.620.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225548.164.jpg',
#  'dataset\\yellow_sportscar\\images (51).jpg',
#  'dataset\\green_bicycle\\images (19).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225542.368.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225535.474.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225417.061.jpg',
#  'dataset\\yellow_sportscar\\images (92).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225409.523.jpg',
#  'dataset\\yellow_sportscar\\images (46).jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225358.136.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225538.620.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230018.995.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225409.298.jpg',
#  'dataset\\red_truck\\keyboard_arrow_right_grey600_24dp.png',
#  'dataset\\red_truck\\images - 2019-10-16T225405.588.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225406.437.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225547.989.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225550.070.jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225551.823.jpg',
#  'dataset\\red_truck\\images - 2019-10-16T225351.634.jpg',
#  'dataset\\green_bicycle\\images (4).png',
#  'dataset\\green_bicycle\\Z (6).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230024.444.jpg',
#  'dataset\\red_truck\\images (10).jpg',
#  'dataset\\yellow_sportscar\\images (84).jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230004.263.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230024.381.jpg',
#  'dataset\\green_bicycle\\images - 2019-10-16T230011.425.jpg',
#  'dataset\\yellow_sportscar\\images (70).jpg',
#  'dataset\\yellow_sportscar\\images - 2019-10-16T225546.441.jpg',
#  ...]

# %%
 'dataset\\yellow_sportscar\\images - 2019-10-16T225546.441.jpg'.split((os.path.sep))[-2]
# Out:
# 'yellow_sportscar'

# %%
#data, labels = ([] for _ in range(2))
data = []
labels = []

# %%
for path in paths:
    img = cv2.imread(path)
    img = cv2.resize(img, (IMAGE_DIMS[1], IMAGE_DIMS[0]))
    img = img_to_array(img)
    data.append(img)
    
    label = path.split(os.path.sep)[-2].split("_")
#     print(label)
    labels.append(label)
#     print(labels)
#     labels = set(labels)

# %%
labels
# Out:
# [['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ['red', 'truck'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['red', 'truck'],
#  ['yellow', 'sportscar'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['green', 'bicycle'],
#  ['yellow', 'sportscar'],
#  ['yellow', 'sportscar'],
#  ...]

# %%
data = np.array()
